# %%
import sys

sys.path.append("../")

# %%
import glob
import pandas as pd

# %%
data_files = glob.glob("../data" + "/*.csv")
data_files
# Out:
# ['../data\\fraud_sample.csv']

# %%
df = pd.read_csv(data_files[0], index_col=0)
df.head()
# Out:
#        trans_date_trans_time               cc_num              merchant  \
# 214458   2020-09-05 12:16:08  4410582919485061752     fraud_Friesen Ltd
# 160855   2020-08-16 21:57:53       30551643947183  fraud_Morissette PLC
# 91817    2020-07-23 00:49:26         630451534402     fraud_Kuvalis Ltd
# 311280   2020-10-17 19:47:15     3551217896304745     fraud_Friesen Inc
# 44803    2020-07-06 17:16:41     6511349151405438     fraud_Windler LLC
#
#               category    amt   first     last gender  \
# 214458  health_fitness   2.81   David     Cole      M
# 160855    shopping_pos   2.78  Morgan    Smith      F
# 91817    gas_transport  53.64  Rachel  Daniels      F
# 311280    shopping_pos   8.06    Sara   Harris      F
# 44803        kids_pets  19.94  Robert   Nguyen      M
#
#                              street         city  ...      lat      long  \
# 214458  7955 Allen Orchard Apt. 336  Springfield  ...  32.3697  -81.3618
# ...

# %%
df.columns
# Out:
# Index(['trans_date_trans_time', 'cc_num', 'merchant', 'category', 'amt',
#        'first', 'last', 'gender', 'street', 'city', 'state', 'zip', 'lat',
#        'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time', 'merch_lat',
#        'merch_long', 'is_fraud'],
#       dtype='object')

# %%
# convert the datetime column to datetime
df['trans_date_trans_time'] = pd.to_datetime(df['trans_date_trans_time'])

# %%
# convert is_fraud column to boolean
df['is_fraud'] = df['is_fraud'].astype(bool)

# %%
df
# Out:
#        trans_date_trans_time               cc_num  \
# 214458   2020-09-05 12:16:08  4410582919485061752
# 160855   2020-08-16 21:57:53       30551643947183
# 91817    2020-07-23 00:49:26         630451534402
# 311280   2020-10-17 19:47:15     3551217896304745
# 44803    2020-07-06 17:16:41     6511349151405438
# ...                      ...                  ...
# 327380   2020-10-24 22:24:43        4169388510116
# 353094   2020-11-04 11:27:09      180069253480336
# 287687   2020-10-06 17:23:46     3540075240003197
# 107671   2020-07-28 13:14:31     4874017206859125
# 123947   2020-08-03 15:46:20     3540210836308425
#
#                             merchant        category     amt      first  \
# 214458             fraud_Friesen Ltd  health_fitness    2.81      David
# 160855          fraud_Morissette PLC    shopping_pos    2.78     Morgan
# 91817              fraud_Kuvalis Ltd   gas_transport   53.64     Rachel
# ...

# %%
df['trans_date_trans_time'].iloc[0]
# Out:
# Timestamp('2020-09-05 12:16:08')

# %%
# fraud_df = df[df['is_fraud'] == 1]
# no_fraud_df = df[df['is_fraud'] == 0]
# concatenated_df = pd.concat([fraud_df[:50], no_fraud_df[:50]])

# %%
engine = "postgresql://myuser:mypassword@localhost:5432/postgres"
df.to_sql("fraud_data", con=engine, index=False, if_exists="replace")
# Out:
# 572
